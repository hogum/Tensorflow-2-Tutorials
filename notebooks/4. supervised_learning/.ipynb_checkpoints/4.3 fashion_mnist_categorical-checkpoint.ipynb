# %% [markdown]
# # Classification

# %% [markdown]
# - An example with the mnist fashion dataset

# %% [markdown]
# Classification deals with categorical variables

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# Initialize Constants

# %%
batch_size = 128
epochs = 30
lr = 0.1
n_classes = 10

# %%
labels = ['shirt', 'trousers', 'pullover', 'dress', 'coat', 'sandal', 'shirt', 'sneaker', 'bag', 'ankle boot']

# %%
# load dataset
mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# Normalize the features

x_train = x_train.astype(np.float32) / 255.
x_test  = x_test.astype(np.float32) / 255.

# Flatten the feature set
img_shape = x_train.shape[1:]
w, h = img_shape

x_train = x_train.reshape([x_train.shape[0], w * h])
x_test = x_test.reshape(x_test.shape[0], w * h)

# %%
# Split the training data to training and validation sets

idx = int(.9 * x_train.shape[0])

x_train, x_valid = x_train[:idx], x_train[idx:,]
y_train, y_valid = y_train[:idx], y_train[idx:,]

# %%
#Use one-hot encoding for the labels

y_train = tf.one_hot(y_train, depth=n_classes).numpy()
y_test = tf.one_hot(y_test, n_classes).numpy()
y_valid = tf.one_hot(y_valid, n_classes).numpy()

# %% [markdown]
# ##### Let's have a look at the dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig=plt.figure(figsize=(8, 8))
columns = 6
rows = 4
for i in range(1, columns*rows +1):
    img = np.reshape(x_train[i], [w, h])
    ax = fig.add_subplot(rows, columns, i)
    ax.set_title(labels[np.argmax(y_train[i])])

    
    plt.imshow(img, cmap='Greys')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Define the model

# %%
class LogRegression(tf.keras.Model):
    def __init__(self, n_classes):
        super(LogRegression, self).__init__()
        self.dense = tf.keras.layers.Dense(n_classes)
    
    def call(self, inputs, training=None, mask=None):
        output_ = self.dense(inputs)
        return tf.nn.softmax(output_)

# %% [markdown]
# #### Build and compile the model

# %%
clf = LogRegression(n_classes)
clf.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy',
           metrics=['accuracy'])

# %%
save_path = './models.1.weights.hdf5'
checkpnt = tf.keras.callbacks.ModelCheckpoint(filepath=save_path,
                                verbose=2,
                                save_best_only=True,
                                save_weights_only=True)

# %%
# train
clf.fit(x_train, y_train,
       batch_size=batch_size, epochs=epochs,
       validation_data=(x_valid, y_valid),
       callbacks=[checkpnt],
       verbose=1)

# Load model with best validation accuracy
clf.load_weights(save_path)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/30
#
# Epoch 00001: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3556 - accuracy: 0.8754 - val_loss: 0.4158 - val_accuracy: 0.8568
# Epoch 2/30
#
# Epoch 00002: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3535 - accuracy: 0.8754 - val_loss: 0.4082 - val_accuracy: 0.8593
# Epoch 3/30
#
# Epoch 00003: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3542 - accuracy: 0.8752 - val_loss: 0.4248 - val_accuracy: 0.8533
# Epoch 4/30
#
# Epoch 00004: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3535 - accuracy: 0.8766 - val_loss: 0.4161 - val_accuracy: 0.8557
# Epoch 5/30
#
# Epoch 00005: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3535 - accuracy: 0.8758 - val_loss: 0.4150 - val_accuracy: 0.8563
# Epoch 6/30
#
# Epoch 00006: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3527 - accuracy: 0.8772 - val_loss: 0.4122 - val_accuracy: 0.8562
# Epoch 7/30
#
# Epoch 00007: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3528 - accuracy: 0.8762 - val_loss: 0.4191 - val_accuracy: 0.8552
# Epoch 8/30
#
# Epoch 00008: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3523 - accuracy: 0.8768 - val_loss: 0.4143 - val_accuracy: 0.8562
# Epoch 9/30
#
# Epoch 00009: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3533 - accuracy: 0.8760 - val_loss: 0.4191 - val_accuracy: 0.8555
# Epoch 10/30
#
# Epoch 00010: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3531 - accuracy: 0.8753 - val_loss: 0.4106 - val_accuracy: 0.8557
# Epoch 11/30
#
# Epoch 00011: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3518 - accuracy: 0.8768 - val_loss: 0.4081 - val_accuracy: 0.8567
# Epoch 12/30
#
# Epoch 00012: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3515 - accuracy: 0.8762 - val_loss: 0.4120 - val_accuracy: 0.8548
# Epoch 13/30
#
# Epoch 00013: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3518 - accuracy: 0.8770 - val_loss: 0.4206 - val_accuracy: 0.8518
# Epoch 14/30
#
# Epoch 00014: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3508 - accuracy: 0.8771 - val_loss: 0.4145 - val_accuracy: 0.8580
# Epoch 15/30
#
# Epoch 00015: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3510 - accuracy: 0.8764 - val_loss: 0.4132 - val_accuracy: 0.8558
# Epoch 16/30
#
# Epoch 00016: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3511 - accuracy: 0.8764 - val_loss: 0.4182 - val_accuracy: 0.8545
# Epoch 17/30
#
# Epoch 00017: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3516 - accuracy: 0.8767 - val_loss: 0.4179 - val_accuracy: 0.8548
# Epoch 18/30
#
# Epoch 00018: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3515 - accuracy: 0.8763 - val_loss: 0.4137 - val_accuracy: 0.8532
# Epoch 19/30
#
# Epoch 00019: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3510 - accuracy: 0.8770 - val_loss: 0.4106 - val_accuracy: 0.8573
# Epoch 20/30
#
# Epoch 00020: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3501 - accuracy: 0.8774 - val_loss: 0.4166 - val_accuracy: 0.8555
# Epoch 21/30
#
# Epoch 00021: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3502 - accuracy: 0.8765 - val_loss: 0.4195 - val_accuracy: 0.8533
# Epoch 22/30
#
# Epoch 00022: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3495 - accuracy: 0.8769 - val_loss: 0.4107 - val_accuracy: 0.8553
# Epoch 23/30
#
# Epoch 00023: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3487 - accuracy: 0.8781 - val_loss: 0.4153 - val_accuracy: 0.8575
# Epoch 24/30
#
# Epoch 00024: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3498 - accuracy: 0.8768 - val_loss: 0.4144 - val_accuracy: 0.8545
# Epoch 25/30
#
# Epoch 00025: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3490 - accuracy: 0.8771 - val_loss: 0.4155 - val_accuracy: 0.8545
# Epoch 26/30
#
# Epoch 00026: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3501 - accuracy: 0.8765 - val_loss: 0.4170 - val_accuracy: 0.8550
# Epoch 27/30
#
# Epoch 00027: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3494 - accuracy: 0.8773 - val_loss: 0.4272 - val_accuracy: 0.8557
# Epoch 28/30
#
# Epoch 00028: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3485 - accuracy: 0.8770 - val_loss: 0.4176 - val_accuracy: 0.8548
# Epoch 29/30
#
# Epoch 00029: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3486 - accuracy: 0.8775 - val_loss: 0.4214 - val_accuracy: 0.8540
# Epoch 30/30
#
# Epoch 00030: val_loss did not improve from 0.40804
# 54000/54000 - 1s - loss: 0.3480 - accuracy: 0.8777 - val_loss: 0.4183 - val_accuracy: 0.8547

# %% [markdown]
# #### Evaluate model

# %%
clf.evaluate(x_test, y_test, batch_size)
# Out:
# 10000/10000 [==============================] - 0s 14us/sample - loss: 0.4477 - accuracy: 0.8459
# [0.447665447807312, 0.8459]

# %% [markdown]
# ##### Let's have a graphical look of how well our trained model predicts

# %%
y_preds = clf.predict(x_test)

# %%
sample_size = 20
cols = 5
rows = 4

fig = plt.figure(figsize=(10, 10))
#fig.subplots_adjust(wspace=.5)

samples = np.random.choice(x_test.shape[0], size=sample_size, replace=False)

for idx, sample in enumerate(samples):
    ax = fig.add_subplot(rows, cols, idx + 1, xticks=[], yticks=[])
    ax.imshow(x_test[idx].reshape(w, h), cmap='Greys')
    
    y_pred = np.argmax(y_preds[idx])
    y_true = np.argmax(y_test[idx])
    
    ax.set_title(f'{labels[y_pred]}',
                color='green' if y_pred == y_true else 'red')

# %% [markdown]
# We see the model predicts the correct labels except for the **shirt** misclassified as a **pullover**
